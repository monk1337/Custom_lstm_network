# %%
# coding: utf-8

#training file for LSTM rnn
import random
import time
import shutil
from tqdm import tqdm
import os 
import numpy as np
import pickle as pk
import tensorflow as tf
import Sentiment_network

epoch = 50

with open('Improved_vector_pad.pkl','rb') as f:
    improved_vector = pk.load(f)
    
with open('labels_pad.pkl','rb') as f:
    labels = pk.load(f)
    
print(len(improved_vector))
print(len(labels))
    
train_data = int(len(improved_vector) * 0.85)
sorted_train_data = improved_vector[:train_data]  # split train_data
labels_sorted_train = labels[:train_data]


sorted_test_data = improved_vector[train_data:]  # split test data
labels_sorted_test = labels[train_data:]
# Out:
# /Users/monk/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# WARNING:tensorflow:From /Users/monk/anaconda3/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.
# 14639
# 14639

# %%
def evaluate_(model, batch_size=50):

    """
    Checking  the test accuracy on testing data set

    :param model:
       current lstm model

    :param batch_size:
       batch size for test data set

    :return:
       mean accuracy of test data set

    :raise:
       if input shape is different from placeholder shape:
          ValueError: Cannot feed value of shape

    """
    sess = tf.get_default_session()

    # batch_data = test_data_in
    # batch_labesl = train_labels

    iteration = len(sorted_test_data) // batch_size

    accuracy = []

    for i in range(iteration):
        batch_data_js = sorted_test_data[i * batch_size:(i + 1) * batch_size]
        labelss       = labels_sorted_test[i * batch_size:(i + 1) * batch_size]
        

        network_out = sess.run(model.output, feed_dict={model.placeholder['sentence']: batch_data_js,
                                                        model.placeholder['label']: labelss,
                                                        model.placeholder['mode']: 1})
        

        accuracy.append(network_out['accuracy'])
    return np.mean(np.array(accuracy))


def train_model(model, batch_size=50):
    """

    :param model:
          current lstm model

    :param batch_size:
          batch size for training

    :print:
          epoch
          iteration
          training_loss
          accuracy

    """
    saver = tf.train.Saver()
    with tf.Session() as sess:

        sess.run(tf.global_variables_initializer())

        iteration = len(sorted_train_data) // batch_size
        print("iteration", iteration)
        time.sleep(5)

        for i in range(epoch):

            for j in range(iteration):
                batch_data_j = np.array(sorted_train_data[j * batch_size:(j + 1) * batch_size])
                labels       = np.array(labels_sorted_train[j * batch_size:(j + 1) * batch_size])
                
                print(batch_data_j.shape)
                print(labels.shape)

                
        
                network_out = sess.run(model.output,
                                          feed_dict={model.placeholder['sentence']: batch_data_j,
                                                     model.placeholder['label']: labels,
                                                     model.placeholder['mode']: 0})

                

                print({'epoch': i,
                       'iteration': j,
                       'training_loss': network_out['loss'],
                       'training_accuracy': network_out['accuracy']
                       })
                
                if j % 100 == 0:
                    with open('iterres.txt', 'a') as f:
                        f.write(str({'epoch': i, 'test_accuracy': evaluate_(model, batch_size=150), 'iteration': j}) + '\n')



#             os.system('mkdir ' + str(i) + 'epoch' + str(j))
#             saver.save(sess, '.' + str(i) + 'epoch' + str(j) + '/' + str(i))

#             print({'epoch': i, 'test_accuracy': evaluate_(model)})
#             with open('epochandresult', 'a') as f:
#                 f.write(str({'epoch': i, 'test_accuracy': evaluate_(model)}) + '\n')
            


if __name__ == "__main__":

    model = Sentiment_network.SentimentNetwork()

    train_model(model)
    
    
    
#     def __init__(self, dropout_value_, 
#                  word_vocab_size_, 
#                  word_embedding_dim_, 
#                  forget_bias_, 
#                  rnn_num_units,
#                  labels_nos,char_vocab_size_, 
#                  char_embedding_dim_):
# Out:
# iteration 248
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 0, 'training_loss': 1.0983225, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 1, 'training_loss': 1.0993454, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 2, 'training_loss': 1.0992352, 'training_accuracy': 0.36}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 3, 'training_loss': 1.100401, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 4, 'training_loss': 1.0992737, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 5, 'training_loss': 1.098535, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 6, 'training_loss': 1.0987349, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 7, 'training_loss': 1.0986973, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 8, 'training_loss': 1.0984015, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 9, 'training_loss': 1.0978577, 'training_accuracy': 0.4}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 10, 'training_loss': 1.0997853, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 11, 'training_loss': 1.1019055, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 12, 'training_loss': 1.101542, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 13, 'training_loss': 1.1014228, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 14, 'training_loss': 1.1012832, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 15, 'training_loss': 1.101464, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 16, 'training_loss': 1.1019013, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 17, 'training_loss': 1.1004657, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 18, 'training_loss': 1.1015977, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 19, 'training_loss': 1.1020975, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 20, 'training_loss': 1.1018323, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 21, 'training_loss': 1.1013827, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 22, 'training_loss': 1.1022189, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 23, 'training_loss': 1.1018525, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 24, 'training_loss': 1.1014812, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 25, 'training_loss': 1.1018349, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 26, 'training_loss': 1.1013117, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 27, 'training_loss': 1.1024133, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 28, 'training_loss': 1.1027179, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 29, 'training_loss': 1.1023139, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 30, 'training_loss': 1.1021253, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 31, 'training_loss': 1.1019781, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 32, 'training_loss': 1.1014912, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 33, 'training_loss': 1.101407, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 34, 'training_loss': 1.1027128, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 35, 'training_loss': 1.1024274, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 36, 'training_loss': 1.102398, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 37, 'training_loss': 1.1007897, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 38, 'training_loss': 1.1015084, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 39, 'training_loss': 1.1026887, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 40, 'training_loss': 1.1013067, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 41, 'training_loss': 1.1025716, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 42, 'training_loss': 1.1018519, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 43, 'training_loss': 1.1025972, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 44, 'training_loss': 1.1013789, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 45, 'training_loss': 1.1017256, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 46, 'training_loss': 1.1018481, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 47, 'training_loss': 1.1012582, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 48, 'training_loss': 1.1016316, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 49, 'training_loss': 1.1016414, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 50, 'training_loss': 1.1020485, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 51, 'training_loss': 1.101328, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 52, 'training_loss': 1.1009084, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 53, 'training_loss': 1.1014329, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 54, 'training_loss': 1.1018234, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 55, 'training_loss': 1.1014291, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 56, 'training_loss': 1.1007538, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 57, 'training_loss': 1.1007451, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 58, 'training_loss': 1.1009346, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 59, 'training_loss': 1.1014059, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 60, 'training_loss': 1.10104, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 61, 'training_loss': 1.101581, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 62, 'training_loss': 1.1005418, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 63, 'training_loss': 1.1013073, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 64, 'training_loss': 1.1023017, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 65, 'training_loss': 1.1012473, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 66, 'training_loss': 1.1002632, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 67, 'training_loss': 1.1015007, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 68, 'training_loss': 1.1002021, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 69, 'training_loss': 1.101641, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 70, 'training_loss': 1.1004472, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 71, 'training_loss': 1.1013707, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 72, 'training_loss': 1.0992085, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 73, 'training_loss': 1.1003946, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 74, 'training_loss': 1.10218, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 75, 'training_loss': 1.1017023, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 76, 'training_loss': 1.1019292, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 77, 'training_loss': 1.101041, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 78, 'training_loss': 1.1018332, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 79, 'training_loss': 1.1018766, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 80, 'training_loss': 1.1008345, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 81, 'training_loss': 1.1020186, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 82, 'training_loss': 1.1013619, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 83, 'training_loss': 1.1006691, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 84, 'training_loss': 1.102047, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 85, 'training_loss': 1.1005231, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 86, 'training_loss': 1.1013163, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 87, 'training_loss': 1.1003304, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 88, 'training_loss': 1.1013618, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 89, 'training_loss': 1.1001211, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 90, 'training_loss': 1.098961, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 91, 'training_loss': 1.0990187, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 92, 'training_loss': 1.098084, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 93, 'training_loss': 1.1001935, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 94, 'training_loss': 1.0997527, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 95, 'training_loss': 1.1001766, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 96, 'training_loss': 1.1006227, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 97, 'training_loss': 1.0980058, 'training_accuracy': 0.4}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 98, 'training_loss': 1.0999452, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 99, 'training_loss': 1.0999757, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 100, 'training_loss': 1.1000764, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 101, 'training_loss': 1.1008611, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 102, 'training_loss': 1.1013824, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 103, 'training_loss': 1.1016983, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 104, 'training_loss': 1.1027128, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 105, 'training_loss': 1.1005931, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 106, 'training_loss': 1.1012822, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 107, 'training_loss': 1.1013261, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 108, 'training_loss': 1.1011826, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 109, 'training_loss': 1.0992787, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 110, 'training_loss': 1.0987575, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 111, 'training_loss': 1.0994948, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 112, 'training_loss': 1.0989432, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 113, 'training_loss': 1.0995677, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 114, 'training_loss': 1.099776, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 115, 'training_loss': 1.1002121, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 116, 'training_loss': 1.0991446, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 117, 'training_loss': 1.0988096, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 118, 'training_loss': 1.099889, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 119, 'training_loss': 1.0987898, 'training_accuracy': 0.36}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 120, 'training_loss': 1.0982225, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 121, 'training_loss': 1.098294, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 122, 'training_loss': 1.0987327, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 123, 'training_loss': 1.09963, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 124, 'training_loss': 1.0985293, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 125, 'training_loss': 1.098894, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 126, 'training_loss': 1.1004436, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 127, 'training_loss': 1.0994297, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 128, 'training_loss': 1.1000413, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 129, 'training_loss': 1.1010307, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 130, 'training_loss': 1.0996746, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 131, 'training_loss': 1.100198, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 132, 'training_loss': 1.101558, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 133, 'training_loss': 1.0995437, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 134, 'training_loss': 1.1009921, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 135, 'training_loss': 1.0991423, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 136, 'training_loss': 1.0979458, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 137, 'training_loss': 1.1001804, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 138, 'training_loss': 1.0983678, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 139, 'training_loss': 1.0980458, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 140, 'training_loss': 1.098457, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 141, 'training_loss': 1.0977486, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 142, 'training_loss': 1.0988469, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 143, 'training_loss': 1.0982972, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 144, 'training_loss': 1.0999718, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 145, 'training_loss': 1.1007066, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 146, 'training_loss': 1.1017027, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 147, 'training_loss': 1.1007286, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 148, 'training_loss': 1.1016068, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 149, 'training_loss': 1.1004326, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 150, 'training_loss': 1.1017332, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 151, 'training_loss': 1.100194, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 152, 'training_loss': 1.1004468, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 153, 'training_loss': 1.1004782, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 154, 'training_loss': 1.0981004, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 155, 'training_loss': 1.1000562, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 156, 'training_loss': 1.0998267, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 157, 'training_loss': 1.0978302, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 158, 'training_loss': 1.0994387, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 159, 'training_loss': 1.1000011, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 160, 'training_loss': 1.0975759, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 161, 'training_loss': 1.0986133, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 162, 'training_loss': 1.0990058, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 163, 'training_loss': 1.1000297, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 164, 'training_loss': 1.0991288, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 165, 'training_loss': 1.0990349, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 166, 'training_loss': 1.0998015, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 167, 'training_loss': 1.1011078, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 168, 'training_loss': 1.0991025, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 169, 'training_loss': 1.0990343, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 170, 'training_loss': 1.099872, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 171, 'training_loss': 1.098431, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 172, 'training_loss': 1.0988624, 'training_accuracy': 0.42}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 173, 'training_loss': 1.0994076, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 174, 'training_loss': 1.099164, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 175, 'training_loss': 1.1017525, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 176, 'training_loss': 1.098885, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 177, 'training_loss': 1.0982971, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 178, 'training_loss': 1.0985155, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 179, 'training_loss': 1.100103, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 180, 'training_loss': 1.1012157, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 181, 'training_loss': 1.1019526, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 182, 'training_loss': 1.1020402, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 183, 'training_loss': 1.1031876, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 184, 'training_loss': 1.1025702, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 185, 'training_loss': 1.1015468, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 186, 'training_loss': 1.1014295, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 187, 'training_loss': 1.1012913, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 188, 'training_loss': 1.1033828, 'training_accuracy': 0.0}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 189, 'training_loss': 1.1019025, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 190, 'training_loss': 1.1025434, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 191, 'training_loss': 1.1013057, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 192, 'training_loss': 1.1027142, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 193, 'training_loss': 1.103004, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 194, 'training_loss': 1.1030431, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 195, 'training_loss': 1.1020472, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 196, 'training_loss': 1.1027634, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 197, 'training_loss': 1.1030385, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 198, 'training_loss': 1.1024542, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 199, 'training_loss': 1.1027671, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 200, 'training_loss': 1.1030575, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 201, 'training_loss': 1.1031698, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 202, 'training_loss': 1.1025703, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 203, 'training_loss': 1.1030383, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 204, 'training_loss': 1.1034752, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 205, 'training_loss': 1.1033558, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 206, 'training_loss': 1.1032133, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 207, 'training_loss': 1.1030091, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 208, 'training_loss': 1.1017482, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 209, 'training_loss': 1.1006243, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 210, 'training_loss': 1.1028134, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 211, 'training_loss': 1.1027648, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 212, 'training_loss': 1.1023703, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 213, 'training_loss': 1.102364, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 214, 'training_loss': 1.103175, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 215, 'training_loss': 1.1010613, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 216, 'training_loss': 1.1011701, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 217, 'training_loss': 1.1014088, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 218, 'training_loss': 1.1026925, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 219, 'training_loss': 1.101901, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 220, 'training_loss': 1.102818, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 221, 'training_loss': 1.1009625, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 222, 'training_loss': 1.1013848, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 223, 'training_loss': 1.1003441, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 224, 'training_loss': 1.1021212, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 225, 'training_loss': 1.1014028, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 226, 'training_loss': 1.1026874, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 227, 'training_loss': 1.1019679, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 228, 'training_loss': 1.1031264, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 229, 'training_loss': 1.1020204, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 230, 'training_loss': 1.1014557, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 231, 'training_loss': 1.1026593, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 232, 'training_loss': 1.1016527, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 233, 'training_loss': 1.1016852, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 234, 'training_loss': 1.1017476, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 235, 'training_loss': 1.1014081, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 236, 'training_loss': 1.1022424, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 237, 'training_loss': 1.1017789, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 238, 'training_loss': 1.1002412, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 239, 'training_loss': 1.1006444, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 240, 'training_loss': 1.1014051, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 241, 'training_loss': 1.099847, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 242, 'training_loss': 1.101725, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 243, 'training_loss': 1.1001918, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 244, 'training_loss': 1.0998125, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 245, 'training_loss': 1.1010264, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 246, 'training_loss': 1.1005046, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 0, 'iteration': 247, 'training_loss': 1.1000001, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 0, 'training_loss': 1.0983225, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 1, 'training_loss': 1.0993454, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 2, 'training_loss': 1.0992352, 'training_accuracy': 0.36}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 3, 'training_loss': 1.100401, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 4, 'training_loss': 1.0992737, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 5, 'training_loss': 1.098535, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 6, 'training_loss': 1.0987349, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 7, 'training_loss': 1.0986973, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 8, 'training_loss': 1.0984015, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 9, 'training_loss': 1.0978577, 'training_accuracy': 0.4}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 10, 'training_loss': 1.0997853, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 11, 'training_loss': 1.1019055, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 12, 'training_loss': 1.101542, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 13, 'training_loss': 1.1014228, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 14, 'training_loss': 1.1012832, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 15, 'training_loss': 1.101464, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 16, 'training_loss': 1.1019013, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 17, 'training_loss': 1.1004657, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 18, 'training_loss': 1.1015977, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 19, 'training_loss': 1.1020975, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 20, 'training_loss': 1.1018323, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 21, 'training_loss': 1.1013827, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 22, 'training_loss': 1.1022189, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 23, 'training_loss': 1.1018525, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 24, 'training_loss': 1.1014812, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 25, 'training_loss': 1.1018349, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 26, 'training_loss': 1.1013117, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 27, 'training_loss': 1.1024133, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 28, 'training_loss': 1.1027179, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 29, 'training_loss': 1.1023139, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 30, 'training_loss': 1.1021253, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 31, 'training_loss': 1.1019781, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 32, 'training_loss': 1.1014912, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 33, 'training_loss': 1.101407, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 34, 'training_loss': 1.1027128, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 35, 'training_loss': 1.1024274, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 36, 'training_loss': 1.102398, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 37, 'training_loss': 1.1007897, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 38, 'training_loss': 1.1015084, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 39, 'training_loss': 1.1026887, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 40, 'training_loss': 1.1013067, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 41, 'training_loss': 1.1025716, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 42, 'training_loss': 1.1018519, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 43, 'training_loss': 1.1025972, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 44, 'training_loss': 1.1013789, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 45, 'training_loss': 1.1017256, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 46, 'training_loss': 1.1018481, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 47, 'training_loss': 1.1012582, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 48, 'training_loss': 1.1016316, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 49, 'training_loss': 1.1016414, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 50, 'training_loss': 1.1020485, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 51, 'training_loss': 1.101328, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 52, 'training_loss': 1.1009084, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 53, 'training_loss': 1.1014329, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 54, 'training_loss': 1.1018234, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 55, 'training_loss': 1.1014291, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 56, 'training_loss': 1.1007538, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 57, 'training_loss': 1.1007451, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 58, 'training_loss': 1.1009346, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 59, 'training_loss': 1.1014059, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 60, 'training_loss': 1.10104, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 61, 'training_loss': 1.101581, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 62, 'training_loss': 1.1005418, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 63, 'training_loss': 1.1013073, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 64, 'training_loss': 1.1023017, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 65, 'training_loss': 1.1012473, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 66, 'training_loss': 1.1002632, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 67, 'training_loss': 1.1015007, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 68, 'training_loss': 1.1002021, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 69, 'training_loss': 1.101641, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 70, 'training_loss': 1.1004472, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 71, 'training_loss': 1.1013707, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 72, 'training_loss': 1.0992085, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 73, 'training_loss': 1.1003946, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 74, 'training_loss': 1.10218, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 75, 'training_loss': 1.1017023, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 76, 'training_loss': 1.1019292, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 77, 'training_loss': 1.101041, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 78, 'training_loss': 1.1018332, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 79, 'training_loss': 1.1018766, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 80, 'training_loss': 1.1008345, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 81, 'training_loss': 1.1020186, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 82, 'training_loss': 1.1013619, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 83, 'training_loss': 1.1006691, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 84, 'training_loss': 1.102047, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 85, 'training_loss': 1.1005231, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 86, 'training_loss': 1.1013163, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 87, 'training_loss': 1.1003304, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 88, 'training_loss': 1.1013618, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 89, 'training_loss': 1.1001211, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 90, 'training_loss': 1.098961, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 91, 'training_loss': 1.0990187, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 92, 'training_loss': 1.098084, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 93, 'training_loss': 1.1001935, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 94, 'training_loss': 1.0997527, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 95, 'training_loss': 1.1001766, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 96, 'training_loss': 1.1006227, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 97, 'training_loss': 1.0980058, 'training_accuracy': 0.4}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 98, 'training_loss': 1.0999452, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 99, 'training_loss': 1.0999757, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 100, 'training_loss': 1.1000764, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 101, 'training_loss': 1.1008611, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 102, 'training_loss': 1.1013824, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 103, 'training_loss': 1.1016983, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 104, 'training_loss': 1.1027128, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 105, 'training_loss': 1.1005931, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 106, 'training_loss': 1.1012822, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 107, 'training_loss': 1.1013261, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 108, 'training_loss': 1.1011826, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 109, 'training_loss': 1.0992787, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 110, 'training_loss': 1.0987575, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 111, 'training_loss': 1.0994948, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 112, 'training_loss': 1.0989432, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 113, 'training_loss': 1.0995677, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 114, 'training_loss': 1.099776, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 115, 'training_loss': 1.1002121, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 116, 'training_loss': 1.0991446, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 117, 'training_loss': 1.0988096, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 118, 'training_loss': 1.099889, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 119, 'training_loss': 1.0987898, 'training_accuracy': 0.36}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 120, 'training_loss': 1.0982225, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 121, 'training_loss': 1.098294, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 122, 'training_loss': 1.0987327, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 123, 'training_loss': 1.09963, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 124, 'training_loss': 1.0985293, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 125, 'training_loss': 1.098894, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 126, 'training_loss': 1.1004436, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 127, 'training_loss': 1.0994297, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 128, 'training_loss': 1.1000413, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 129, 'training_loss': 1.1010307, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 130, 'training_loss': 1.0996746, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 131, 'training_loss': 1.100198, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 132, 'training_loss': 1.101558, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 133, 'training_loss': 1.0995437, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 134, 'training_loss': 1.1009921, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 135, 'training_loss': 1.0991423, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 136, 'training_loss': 1.0979458, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 137, 'training_loss': 1.1001804, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 138, 'training_loss': 1.0983678, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 139, 'training_loss': 1.0980458, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 140, 'training_loss': 1.098457, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 141, 'training_loss': 1.0977486, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 142, 'training_loss': 1.0988469, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 143, 'training_loss': 1.0982972, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 144, 'training_loss': 1.0999718, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 145, 'training_loss': 1.1007066, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 146, 'training_loss': 1.1017027, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 147, 'training_loss': 1.1007286, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 148, 'training_loss': 1.1016068, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 149, 'training_loss': 1.1004326, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 150, 'training_loss': 1.1017332, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 151, 'training_loss': 1.100194, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 152, 'training_loss': 1.1004468, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 153, 'training_loss': 1.1004782, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 154, 'training_loss': 1.0981004, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 155, 'training_loss': 1.1000562, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 156, 'training_loss': 1.0998267, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 157, 'training_loss': 1.0978302, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 158, 'training_loss': 1.0994387, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 159, 'training_loss': 1.1000011, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 160, 'training_loss': 1.0975759, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 161, 'training_loss': 1.0986133, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 162, 'training_loss': 1.0990058, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 163, 'training_loss': 1.1000297, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 164, 'training_loss': 1.0991288, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 165, 'training_loss': 1.0990349, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 166, 'training_loss': 1.0998015, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 167, 'training_loss': 1.1011078, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 168, 'training_loss': 1.0991025, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 169, 'training_loss': 1.0990343, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 170, 'training_loss': 1.099872, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 171, 'training_loss': 1.098431, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 172, 'training_loss': 1.0988624, 'training_accuracy': 0.42}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 173, 'training_loss': 1.0994076, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 174, 'training_loss': 1.099164, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 175, 'training_loss': 1.1017525, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 176, 'training_loss': 1.098885, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 177, 'training_loss': 1.0982971, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 178, 'training_loss': 1.0985155, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 179, 'training_loss': 1.100103, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 180, 'training_loss': 1.1012157, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 181, 'training_loss': 1.1019526, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 182, 'training_loss': 1.1020402, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 183, 'training_loss': 1.1031876, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 184, 'training_loss': 1.1025702, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 185, 'training_loss': 1.1015468, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 186, 'training_loss': 1.1014295, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 187, 'training_loss': 1.1012913, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 188, 'training_loss': 1.1033828, 'training_accuracy': 0.0}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 189, 'training_loss': 1.1019025, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 190, 'training_loss': 1.1025434, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 191, 'training_loss': 1.1013057, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 192, 'training_loss': 1.1027142, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 193, 'training_loss': 1.103004, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 194, 'training_loss': 1.1030431, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 195, 'training_loss': 1.1020472, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 196, 'training_loss': 1.1027634, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 197, 'training_loss': 1.1030385, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 198, 'training_loss': 1.1024542, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 199, 'training_loss': 1.1027671, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 200, 'training_loss': 1.1030575, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 201, 'training_loss': 1.1031698, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 202, 'training_loss': 1.1025703, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 203, 'training_loss': 1.1030383, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 204, 'training_loss': 1.1034752, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 205, 'training_loss': 1.1033558, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 206, 'training_loss': 1.1032133, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 1, 'iteration': 207, 'training_loss': 1.1030091, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# ...
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 99, 'training_loss': 1.0999757, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 100, 'training_loss': 1.1000764, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 101, 'training_loss': 1.1008611, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 102, 'training_loss': 1.1013824, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 103, 'training_loss': 1.1016983, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 104, 'training_loss': 1.1027128, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 105, 'training_loss': 1.1005931, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 106, 'training_loss': 1.1012822, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 107, 'training_loss': 1.1013261, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 108, 'training_loss': 1.1011826, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 109, 'training_loss': 1.0992787, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 110, 'training_loss': 1.0987575, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 111, 'training_loss': 1.0994948, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 112, 'training_loss': 1.0989432, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 113, 'training_loss': 1.0995677, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 114, 'training_loss': 1.099776, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 115, 'training_loss': 1.1002121, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 116, 'training_loss': 1.0991446, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 117, 'training_loss': 1.0988096, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 118, 'training_loss': 1.099889, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 119, 'training_loss': 1.0987898, 'training_accuracy': 0.36}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 120, 'training_loss': 1.0982225, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 121, 'training_loss': 1.098294, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 122, 'training_loss': 1.0987327, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 123, 'training_loss': 1.09963, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 124, 'training_loss': 1.0985293, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 125, 'training_loss': 1.098894, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 126, 'training_loss': 1.1004436, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 127, 'training_loss': 1.0994297, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 128, 'training_loss': 1.1000413, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 129, 'training_loss': 1.1010307, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 130, 'training_loss': 1.0996746, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 131, 'training_loss': 1.100198, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 132, 'training_loss': 1.101558, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 133, 'training_loss': 1.0995437, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 134, 'training_loss': 1.1009921, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 135, 'training_loss': 1.0991423, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 136, 'training_loss': 1.0979458, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 137, 'training_loss': 1.1001804, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 138, 'training_loss': 1.0983678, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 139, 'training_loss': 1.0980458, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 140, 'training_loss': 1.098457, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 141, 'training_loss': 1.0977486, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 142, 'training_loss': 1.0988469, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 143, 'training_loss': 1.0982972, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 144, 'training_loss': 1.0999718, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 145, 'training_loss': 1.1007066, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 146, 'training_loss': 1.1017027, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 147, 'training_loss': 1.1007286, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 148, 'training_loss': 1.1016068, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 149, 'training_loss': 1.1004326, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 150, 'training_loss': 1.1017332, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 151, 'training_loss': 1.100194, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 152, 'training_loss': 1.1004468, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 153, 'training_loss': 1.1004782, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 154, 'training_loss': 1.0981004, 'training_accuracy': 0.44}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 155, 'training_loss': 1.1000562, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 156, 'training_loss': 1.0998267, 'training_accuracy': 0.24}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 157, 'training_loss': 1.0978302, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 158, 'training_loss': 1.0994387, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 159, 'training_loss': 1.1000011, 'training_accuracy': 0.22}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 160, 'training_loss': 1.0975759, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 161, 'training_loss': 1.0986133, 'training_accuracy': 0.38}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 162, 'training_loss': 1.0990058, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 163, 'training_loss': 1.1000297, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 164, 'training_loss': 1.0991288, 'training_accuracy': 0.32}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 165, 'training_loss': 1.0990349, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 166, 'training_loss': 1.0998015, 'training_accuracy': 0.26}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 167, 'training_loss': 1.1011078, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 168, 'training_loss': 1.0991025, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 169, 'training_loss': 1.0990343, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 170, 'training_loss': 1.099872, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 171, 'training_loss': 1.098431, 'training_accuracy': 0.18}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 172, 'training_loss': 1.0988624, 'training_accuracy': 0.42}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 173, 'training_loss': 1.0994076, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 174, 'training_loss': 1.099164, 'training_accuracy': 0.3}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 175, 'training_loss': 1.1017525, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 176, 'training_loss': 1.098885, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 177, 'training_loss': 1.0982971, 'training_accuracy': 0.28}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 178, 'training_loss': 1.0985155, 'training_accuracy': 0.34}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 179, 'training_loss': 1.100103, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 180, 'training_loss': 1.1012157, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 181, 'training_loss': 1.1019526, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 182, 'training_loss': 1.1020402, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 183, 'training_loss': 1.1031876, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 184, 'training_loss': 1.1025702, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 185, 'training_loss': 1.1015468, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 186, 'training_loss': 1.1014295, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 187, 'training_loss': 1.1012913, 'training_accuracy': 0.14}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 188, 'training_loss': 1.1033828, 'training_accuracy': 0.0}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 189, 'training_loss': 1.1019025, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 190, 'training_loss': 1.1025434, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 191, 'training_loss': 1.1013057, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 192, 'training_loss': 1.1027142, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 193, 'training_loss': 1.103004, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 194, 'training_loss': 1.1030431, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 195, 'training_loss': 1.1020472, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 196, 'training_loss': 1.1027634, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 197, 'training_loss': 1.1030385, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 198, 'training_loss': 1.1024542, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 199, 'training_loss': 1.1027671, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 200, 'training_loss': 1.1030575, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 201, 'training_loss': 1.1031698, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 202, 'training_loss': 1.1025703, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 203, 'training_loss': 1.1030383, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 204, 'training_loss': 1.1034752, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 205, 'training_loss': 1.1033558, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 206, 'training_loss': 1.1032133, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 207, 'training_loss': 1.1030091, 'training_accuracy': 0.06}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 208, 'training_loss': 1.1017482, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 209, 'training_loss': 1.1006243, 'training_accuracy': 0.2}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 210, 'training_loss': 1.1028134, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 211, 'training_loss': 1.1027648, 'training_accuracy': 0.02}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 212, 'training_loss': 1.1023703, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 213, 'training_loss': 1.102364, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 214, 'training_loss': 1.103175, 'training_accuracy': 0.04}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 215, 'training_loss': 1.1010613, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 216, 'training_loss': 1.1011701, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 217, 'training_loss': 1.1014088, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 218, 'training_loss': 1.1026925, 'training_accuracy': 0.08}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 219, 'training_loss': 1.101901, 'training_accuracy': 0.12}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 220, 'training_loss': 1.102818, 'training_accuracy': 0.1}
# (50, 35, 356)
# (50,)
# {'epoch': 2, 'iteration': 221, 'training_loss': 1.1009625, 'training_accuracy': 0.16}
# (50, 35, 356)
# (50,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-2b97619858af> in <module>()
#     109     model = Sentiment_network.SentimentNetwork()
#     110
# --> 111     train_model(model)
#     112
#     113
#
# <ipython-input-2-2b97619858af> in train_model(model, batch_size)
#      80                                           feed_dict={model.placeholder['sentence']: batch_data_j,
#      81                                                      model.placeholder['label']: labels,
# ---> 82                                                      model.placeholder['mode']: 0})
#      83
#      84
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1138     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1139       results = self._do_run(handle, final_targets, final_fetches,
# -> 1140                              feed_dict_tensor, options, run_metadata)
#    1141     else:
#    1142       results = []
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1321                            run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1310       self._extend_graph()
#    1311       return self._call_tf_sessionrun(
# -> 1312           options, feed_dict, fetch_list, target_list, run_metadata)
#    1313
#    1314     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1418         return tf_session.TF_Run(
#    1419             self._session, options, feed_dict, fetch_list, target_list,
# -> 1420             status, run_metadata)
#    1421
#    1422   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
